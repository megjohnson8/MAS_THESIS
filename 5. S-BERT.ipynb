# %% [markdown]
# # 5. S-BERT

# %% [markdown]
# S-BERT source: https://www.sbert.net/docs/pretrained_models.html

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('all-distilroberta-v1')

# %%
movie_df = pd.read_csv('/Users/meg/Thesis/movie_df_final.csv')
movie_df = movie_df.drop(['Unnamed: 0'], axis=1)
movie_df
# Out:
#        Plot_Words_Len  index  Release Year                             Title  \
# 0                 372   3253          1942          Bugs Bunny Gets the Boid
# 1                  67   6880          1957                    This Angry Age
# 2                 181  32401          2001              Timeranger vs. GoGoV
# 3                  74  25414          1998                       Aunty No. 1
# 4                 693  21147          2014           Dead Snow: Red vs. Dead
# ...               ...    ...           ...                               ...
# 33515             581  16734          2014                   Life After Beth
# 33516             522  16304          2012                   Goodbye Promise
# 33517             458     79          1914  His Majesty, the Scarecrow of Oz
# 33518             259  12119          1994                           Go Fish
# 33519             435  14147          2003                    Darkness Falls
#
# ...

# %%
# %%time
document_embeddings = sbert_model.encode(movie_df['Plot'])
# Out:
# CPU times: user 3h 55min 35s, sys: 49min 57s, total: 4h 45min 33s
# Wall time: 3h 43min 30s

# %%
document_embeddings
# Out:
# array([[-0.03428487, -0.03182422,  0.02842968, ..., -0.03139663,
#         -0.10956897,  0.02465163],
#        [ 0.02949032, -0.06343137, -0.03731328, ..., -0.03032926,
#         -0.0108685 , -0.01044366],
#        [-0.01637044, -0.0145149 ,  0.03311976, ..., -0.06035805,
#          0.00594777,  0.01807209],
#        ...,
#        [ 0.03824263, -0.03893686,  0.02294409, ...,  0.00815722,
#         -0.0283557 , -0.03769142],
#        [ 0.03058658, -0.03294544, -0.02043026, ..., -0.03343879,
#          0.03189389,  0.02412542],
#        [-0.00429649, -0.01301496,  0.03984737, ...,  0.00132852,
#          0.0315534 , -0.04766215]], dtype=float32)

# %%
document_embeddings.shape
# Out:
# (33520, 768)

# %%
document_embeddings_df = pd.DataFrame(document_embeddings)

# %%
document_embeddings_df
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.034285 -0.031824  0.028430 -0.027122  0.046549  0.057665 -0.037256
# 1      0.029490 -0.063431 -0.037313  0.004461  0.043963  0.023274  0.006403
# 2     -0.016370 -0.014515  0.033120 -0.014311 -0.027932  0.033203 -0.015344
# 3     -0.007699 -0.075538 -0.016379 -0.036981  0.020184  0.009692 -0.017110
# 4      0.005997 -0.052268  0.006961 -0.018592 -0.020641  0.107525  0.010658
# ...         ...       ...       ...       ...       ...       ...       ...
# 33515 -0.029403 -0.051794  0.015013 -0.026571  0.044210  0.080169 -0.008186
# 33516 -0.027621 -0.044829 -0.008806 -0.042441  0.063746  0.077213 -0.008617
# 33517  0.038243 -0.038937  0.022944 -0.054369  0.059253  0.070650 -0.017436
# 33518  0.030587 -0.032945 -0.020430  0.017951  0.052579  0.103768  0.016555
# 33519 -0.004296 -0.013015  0.039847 -0.036288  0.087186  0.022701 -0.005091
#
# ...

# %%
document_embeddings_df.to_csv('S_BERT_embeddings.csv')
